# %%
import numpy as np
import pandas as pd
import matplotlib. pyplot as plt
# %matplotlib inline
import csv
import seaborn as sns

# %%
WasteDisposal = pd.read_csv("datasets.csv")

# %%
WasteDisposal
WasteDisposal.dropna()
##projection of waste generation by region 2010-2019##
# Out:
#                       Region    2010    2011    2012    2013    2014    2015  \
# 0                PHILIPPINES  48,070  48,979  49,918  50,874  51,850  52,640
# 1                        NCR   7,400   7,524   7,661   7,795   7,933   8,054
# 2                        CAR     742     754     767     779     792     796
# 3          I - Ilocos Region   2,236   2,263   2,290   2,317   2,345   2,368
# 4        II - Cagayan Valley   1,474   1,493   1,514   1,534   1,555   1,575
# 5        III - Central Luzon   5,383   5,496   5,611   5,728   5,848   5,976
# 6          IV-A - CALABARZON   6,929   7,136   7,349   7,568   7,795   7,958
# 7                   MIMAROPA   1,273   1,296   1,319   1,343   1,367   1,383
# 8           V - Bicol Region   2,466   2,501   2,536   2,571   2,607   2,644
# 9       VI - Western Visayas   3,599   3,645   3,691   3,737   3,785   3,815
# 10     VII - Central Visayas   3,544   3,608   3,674   3,741   3,810   3,865
# ...

# %%
description=WasteDisposal.describe().T
print(description)
# Out:
#        count unique          top freq
# Region    19     19  PHILIPPINES    1
# 2010      18     18       48,070    1
# 2011      18     18       48,979    1
# 2012      18     18       49,918    1
# 2013      18     18       50,874    1
# 2014      18     18       51,850    1
# 2015      18     18       52,640    1
# 2016      18     18       53,653    1
# 2017      18     18       54,690    1
# 2018      18     18       56,485    1
# 2019      18     18       57,579    1

# %%
Waste_data = {'NCR':10000, 'CAR':849, 'I-Ilocos Region':2483, 'II-Cagayan Valley':1662, 'III-Central Luzon':6500, 'IV-A-CALABARZON':8960, 
             'MIMAROPA':1487, 'V-Bicol Region':2794, 'VI-Western Visayas':4007, 'VII-Central Visayas':4160, 'VIII-Eastern Visayas':2038, 
              'IX-Zamboanga Peninsula':1920, 'X-Northern Mindanao':2624, 'XI-Davao Region':3086, 'XII-SOCCSKSARGEN':2704, 'XIII-Caraga':1364, 'ARMM':1608}
Disposal_set = list(Waste_data.keys())
Data_sets = list(Waste_data.values())


plt.figure(figsize=(15,8))
plt.bar(Disposal_set, Data_sets, color ='green', width=0.5)
plt.xlabel('Region')
plt.ylabel('2019')
plt.title('projection of waste generation by region 2010-2019')
plt.show()

# %%
regData = pd.read_csv("RegData.csv")

# %%
regData
# Out:
#                       Region  2010  2011  2012  2013  2014  2015  2016  2017  \
# 0                Philippines   124   127   130   127   114   123   135   128
# 1                        NCR    18    17    22    21    23    20    23    21
# 2                        CAR     0     1     0     0     0     0     0     2
# 3          I - Ilocos Region     3     3     3     3     5     3     3     3
# 4        II - Cagayan Valley     0     0     0     0     0     0     0     0
# 5        III - Central Luzon    24    26    27    26    28    31    32    36
# 6          IV-A - CALABARZON    42    46    41    45    36    38    42    34
# 7                   MIMAROPA     0     0     1     0     0     1     0     1
# 8           V - Bicol Region     3     2     1     1     1     0     1     2
# 9       VI - Western Visayas     4     4     3     1     1     1     1     2
# 10     VII - Central Visayas    11    12     8     8     6    13    11    11
# ...

# %%
description=regData.describe().T
print(description)
# Out:
#       count       mean        std  min  25%  50%   75%    max
# 2010   17.0  14.588235  30.315134  0.0  0.0  3.0  11.0  124.0
# 2011   17.0  14.941176  31.299901  0.0  0.0  4.0  12.0  127.0
# 2012   17.0  15.294118  31.762330  0.0  1.0  3.0  14.0  130.0
# 2013   17.0  14.941176  31.429426  0.0  0.0  2.0  15.0  127.0
# 2014   17.0  13.411765  28.182572  0.0  0.0  1.0   9.0  114.0
# 2015   17.0  14.470588  30.243011  0.0  0.0  2.0  13.0  123.0
# 2016   17.0  15.882353  33.116994  0.0  0.0  3.0  11.0  135.0
# 2017   17.0  15.058824  31.271933  0.0  2.0  2.0  11.0  128.0
# 2018   17.0  15.529412  32.363401  0.0  0.0  3.0  11.0  132.0
# 2019   17.0  15.411765  32.278202  0.0  1.0  2.0  11.0  131.0

# %%
description = regData.describe()
plt.figure(figsize=(12, 8))

description.loc['mean'].plot(kind='bar')

plt.xlabel('Columns')
plt.ylabel('Mean')
plt.title('Mean Values of Columns Registered')

plt.show()

# %%
description = regData.describe()

# Extract the statistics you want to visualize
statistics = description.loc[['count', 'mean', 'std', 'min', '25%', '50%']]

# Transpose the DataFrame for easier plotting
statistics = statistics.T

# Adjust figure size
plt.figure(figsize=(12, 8))

# Plotting the line graph
statistics.plot(kind='line', marker='o')

# Adding labels and title
plt.xlabel('Columns')
plt.ylabel('Value')
plt.title('Descriptive Statistics')

# Adjust font size
plt.xticks(range(len(statistics.index)), statistics.index, fontsize=8)
plt.xticks(rotation=90)
# Display the plot
plt.legend(loc='upper right')
plt.grid(True)
plt.tight_layout()
plt.show()
